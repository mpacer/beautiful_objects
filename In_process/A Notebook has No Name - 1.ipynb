# %%
from IPython.core.formatters import BaseFormatter
from traitlets import Unicode

class FooFormatter(BaseFormatter):
    format_type = Unicode('foo/bar')
    
def repr_foo(obj):
    return "this is a repr foo"
ipython = get_ipython()
foo = FooFormatter()
foo = ipython.display_formatter.formatters['foo/bar'] = foo
foo.for_type(list, repr_foo)

# %%
[]
# Out:
# []

# %%
# !cat A\ Notebook\ has\ No\ Name\ -\ 1.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from IPython.core.formatters import BaseFormatter\n",
#     "from traitlets import Unicode\n",
#     "\n",
#     "class FooFormatter(BaseFormatter):\n",
#     "    format_type = Unicode('foo/bar')\n",
#     "\n",
#     "    \n",
#     "def repr_foo(obj):\n",
#     "    return \"this is a repr foo\"\n",
#     "ipython = get_ipython()\n",
#     "foo = FooFormatter()\n",
#     "foo = ipython.display_formatter.formatters['foo/bar'] = foo\n",
#     "foo.for_type(list, repr_foo)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 4,
#    "metadata": {},
#    "outputs": [
#     {
#      "data": {
#       "foo/bar": "this is a repr foo",
#       "text/plain": [
#        "[]"
#       ]
#      },
#      "execution_count": 4,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "[]"
#    ]
# ...
